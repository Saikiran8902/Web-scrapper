# %%
import pandas as pd

# %%
df=pd.read_excel(r'Web Scraping Assignment.xlsx')
df
# Out:
#          ,                                       COLLEGE NAME  \
# 0      1.0      Abhinava Bharathi College of Pharmacy, Mandya
# 1      2.0           Academy Of Management Studies, Hyderabad
# 2      3.0             Academy Of Mass Communication, Lucknow
# 3      4.0  Acharaya Shri Chander College Of Medical Scien...
# 4      5.0  Acharya Institutes of Science & Management, Ba...
# ..     ...                                                ...
# 495  496.0  Maulana Azad Institute Of Dental Sciences, New...
# 496  497.0              Mawlai Presbyterian College, Shillong
# 497  498.0           Mawsynram Border Area College, Mawsynram
# 498  499.0                        Mayai Lambi College, Imphal
# 499  500.0                      MBTS Govt Polytechnic, GUNTUR
#
#                                         WEBSITE  ADRESS
# 0                                           NaN     NaN
# 1                        http://www.useams.org/     NaN
# ...

# %%
df.columns
# Out:
# Index([',', 'COLLEGE NAME', ' WEBSITE', 'ADRESS'], dtype='object')

# %%
df.dtypes
# Out:
# ,               float64
# COLLEGE NAME     object
#  WEBSITE         object
# ADRESS          float64
# dtype: object

# %%
l=df[' WEBSITE'].values.tolist()
l
# Out:
# [nan,
#  'http://www.useams.org/',
#  'https://www.amclko.org/',
#  'http://ascomscollege.com/',
#  'https://www.acharya.ac.in/',
#  'https://pgcollegekawardha.edu.in/',
#  'http://acmecollege.com/',
#  'http://www.adarshcollegeedu.co.in/ContactUs.aspx',
#  'http://www.adhiyamaanpolytech.in/',
#  'https://www.aec.edu.in/',
#  'http://www.adityatekkali.edu.in/',
#  'https://www.asci.org.in/',
#  'http://www.agmc.nic.in/',
#  'https://www.ainsahmedabad.org/',
#  'https://atc.edu.in/',
#  nan,
#  'https://ammcollege.in/',
#  'https://alhafeezcollege.org/',
#  'https://alipurduarcollege.ac.in/',
#  'https://www.aiimsjodhpur.edu.in/',
#  'https://aiimsbhopal.edu.in/index_controller/index',
#  'http://www.aceatech.com/',
#  'http://actripura.edu.in/',
#  'https://aimsbschool.org/',
#  'https://www.amity.edu/jaipur/abs/',
#  'http://amjadalikhancollege.edu.in/',
#  'http://ampatidegreecollege.in/',
#  'https://www.accommercejpg.org/',
#  'https://www.actrainingcollege.org/',
# ...

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install BeautifulSoup
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-4ohsu7ql\\beautifulsoup_0658ae16f16a4a5c95a91a9f5fbbafc2\\setup.py'"'"'; __file__='"'"'C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-4ohsu7ql\\beautifulsoup_0658ae16f16a4a5c95a91a9f5fbbafc2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\HP\AppData\Local\Temp\pip-pip-egg-info-620_xt10'
# ...

# %%
import requests
from bs4 import BeautifulSoup
l1=[]
for i in l:
    if str(i).startswith(('http://', 'https://')):
        try:
            response = requests.get(str(i),verify=False)
        except requests.exceptions.ConnectionError as e:
            l1.append(' ')
        else:
            if(str(i)=='https://ammcollege.in/'):
                l1.append(' ')
                continue
            soup = BeautifulSoup(response.text, 'html.parser')
            address = soup.find('div', {'id': 'Address'})
            if(address):
                l1.append(address.text.strip())
            else:
                l1.append(' ')
l1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.amclko.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.acharya.ac.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pgcollegekawardha.edu.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
url = 'http://www.useams.org/'

# Send an HTTP request to the URL of the webpage you want to access
response = requests.get(url)

# Parse the content of the webpage with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the element containing the address
address_element = soup.find('div', {'class': 'adr'})

# Extract the text from the element
if address_element is not None:
    address = address_element.get_text(strip=True)
else:
    address = ''

# Print the address
print(address)
# Out:
# 2nd Floor, Manzil Chambers,Mehdipatnam X Roads,HYD500028

# %%
url = 'https://www.acharya.ac.in/'

# Send an HTTP request to the URL of the webpage you want to access
response = requests.get(url)

# Parse the content of the webpage with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the element containing the address
address_element = soup.find('div', {'id': 'address'})

# Extract the text from the element
if address_element is not None:
    address = address_element.get_text(strip=True)
else:
    address = ''

# Print the address
print(address)
# Out:
# AddressAcharya InstitutesAcharya Dr. S. Radhakrishnan RoadAcharya P.O SoladevanahalliBangalore-560107Karnataka, IndiaDomesticadmissions@acharya.ac.in+91 740-664-4449+91 973-179-7677Internationalinternational@acharya.ac.in+91 973-177-9233+91 973-179-7677InstitutesAcharya Institute of Technology »Acharya's NRV School of Architecture »Acharya & BM Reddy College of Pharmacy »Acharya Institute of Graduate Studies »Acharya School of Design »Acharya Institute of Allied Health Sciences »Acharya's NR Institute of Physiotherapy »Smt. Nagarathnamma School of Nursing »Smt. Nagarathnamma College of Nursing »Acharya Polytechnic »Acharya Institute of English & Foreign Languages »Quick linksCampus Life »Infrastructure »Training »Placement »Career »Travel Guidelines »Reach us »Route Map »Students Grievance »Administration »Acharya PortalsStudent LoginEmployee Login

# %%
# url = 'https://pgcollegekawardha.edu.in/contact-us.aspx'

# Send an HTTP request to the URL of the webpage you want to access
response = requests.get(url)

# Parse the content of the webpage with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the element containing the address
address_element = soup.find('div', {'class': 'single-con-add-text'})

# Extract the text from the element
if address_element is not None:
    address = address_element.get_text(strip=True)
else:
    address = ''

# Print the address
print(address)

# %% [markdown]
# # The dataset given was very large it's become difficult to calculate the address of the college because while using web scrapper we have to give the respective div like class, id which was different from each other and also the id and class name of each of the college is also different
